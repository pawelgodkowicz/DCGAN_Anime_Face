# %% [markdown]
# # DCGAN - Anime Faces

# %% [markdown]
# This notebook demonstrates how to generate images of anime faces using a Deep Convolutional Generative Adversarial Network (DCGAN).
#
# The dataset was downloaded from kaggle site: https://www.kaggle.com/soumikrakshit/anime-faces.
#
# Generative Adversarial Networks (GANs) are one of the most interesting ideas in computer science today. Two models are trained simultaneously by an adversarial process. A generator ("the fraud") learns to create images that look real, while a discriminator ("judge") learns to tell real images apart from fakes.
#
# During training, the generator progressively becomes better at creating images that look real, while the discriminator becomes better at telling them apart. The process reaches equilibrium when the discriminator can no longer distinguish real images from fakes.

# %% [markdown]
# ## 1. Package importing.

# %%
from tensorflow.keras.layers import Input, Reshape, Dropout, Dense, Flatten, LeakyReLU, Conv2D, Conv2DTranspose
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import BatchNormalization, Activation, ReLU
from tensorflow.keras.optimizers import Adam

import seaborn
import matplotlib.pyplot as plt
import matplotlib.gridspec as gs

import pandas as pd
from tqdm.notebook import tqdm
import imageio
import glob
import numpy as np
from PIL import Image

# %% [markdown]
# ## 2. Architecture and utilities.

# %% [markdown]
# Both the generator and discriminator are defined using the Keras Functional API. The generator uses Conv2D and Conv2DTranspose (upsampling) layers to produce an image from a seed (random noise). Start with a Dense layer that takes this seed as input, then upsample several times until you reach the desired image size of 64x64x3. The LeakyReLU activation function for each layer, except the output layer which uses tanh.

# %%
def make_generator(noise_shape):
    
    #The Adam optimization algorithm
    optimizer = Adam(lr=0.0002, beta_1=0.5)
    
    generator_input = Input(shape=(noise_shape))
    
    # fully conected layers
    g = Dense(128 * 16 * 16)(generator_input) 
    g = LeakyReLU(0.2)(g) 
    g = Reshape((16, 16, 128))(g)
    
    g = Conv2D(256, 5, padding='same')(g) 
    g = LeakyReLU(0.2)(g)
    # upsample to 16x16
    g = Conv2DTranspose(256, (4,4), strides=(2,2), padding='same')(g) 
    g = LeakyReLU(0.2)(g)
    # upsample to 32x32
    g = Conv2DTranspose(256, (4,4), strides=(2,2), padding='same')(g) 
    g = LeakyReLU(0.2)(g)
    # upsample to 64x64
    g = Conv2D(256, 5, padding='same')(g) 
    g = LeakyReLU(0.2)(g)

    g = Conv2D(3, 8, activation='tanh', padding='same')(g)

    generator_model = Model(generator_input, g)
    generator_model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    print(20*'*' + ' Generator model '+ 20*'*')
    generator_model.summary()

    return generator_model

# %% [markdown]
# The discriminator is a CNN-based image classifier.

# %%
def make_discriminator(image_shape):
    
    optimizer = Adam(lr=0.0002, beta_1=0.5)

    discriminator_input = Input(shape=image_shape)
    d = Conv2D(128, 3, padding='same')(discriminator_input)
    d = LeakyReLU(0.2)(d)
    # downsample to 30x30
    d = Conv2D(128, 5, strides=(2,2))(d)
    d = LeakyReLU(0.2)(d)
    # downsample to 13x13
    d = Conv2D(128, 5, strides=(2,2))(d)
    d = LeakyReLU(0.2)(d)
    # downsample to 5x5
    d = Conv2D(128, 5, strides=(2,2))(d)
    d = LeakyReLU(0.2)(d)
    
    
    # Flatten the input image
    d = Flatten()(d)
    d = Dropout(0.4)(d)
    d = Dense(1, activation='sigmoid')(d)

    discriminator_model = Model(discriminator_input, d)
    discriminator_model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    print(20*'*' + ' Discriminator model '+ 20*'*')
    discriminator_model.summary()
    
    return discriminator_model

# %%
def norm_img(img):
    '''Image normalisation to keep values between -1 and 1 for stability.'''
    images = np.array(img)
    images = (images / 127.5) - 1
    images = images.astype('float32')
    return images

def denorm_img(img):
    '''Image transformation to original.'''
    img = (img + 1) * 127.5
    return img.astype(np.uint8)

def get_data():
    '''Importing data from a working directory'''
    all_images = []
    for index, filename in enumerate(glob.glob(data_dir)):
        image = imageio.imread(filename, as_gray=False, pilmode='RGB')
        all_images.append(image)
        
    return norm_img(all_images)

# %% [markdown]
# DCGAN Model

# %%
def make_gan(g, d):
    optimizer = Adam(lr=0.0002, beta_1=0.5)
    
    # Combined Generator -> Discriminator model
    generator_input = Input(shape=noise_shape)
    gan_input = g(generator_input)
    gan_output = d(gan_input)
    
    gan = Model(generator_input, gan_output)
    gan.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    
    print(10*'*' + ' Generative Adversarial Networks Model '+ 10*'*'   )
    gan.summary()
    
    return gan

# %% [markdown]
# ## 3. Model and data loading.

# %%
noise_shape = (1, 1, 100)
image_shape = (64,64,3)

discriminator = make_discriminator(image_shape=image_shape)
generator = make_generator(noise_shape=noise_shape)
# Keep Discriminator’s parameters constant for Generator training
discriminator.trainable = False

# Build and compile GAN model with fixed Discriminator to train the Generator
gan = make_gan(generator, discriminator)
# Out:
# ******************** Discriminator model ********************
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 64, 64, 3)]       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 64, 64, 128)       3584
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 64, 64, 128)       0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 30, 128)       409728
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 13, 13, 128)       409728
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 13, 13, 128)       0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 5, 5, 128)         409728
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 5, 5, 128)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 3200)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 3200)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 3201
# =================================================================
# Total params: 1,235,969
# Trainable params: 1,235,969
# Non-trainable params: 0
# _________________________________________________________________
# ******************** Generator model ********************
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 1, 1, 100)]       0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1, 1, 32768)       3309568
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 1, 1, 32768)       0
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_7 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_transpose_8 (Conv2DTr (None, 64, 64, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 64, 64, 256)       0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 64, 64, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 64, 64, 256)       0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 64, 64, 3)         49155
# =================================================================
# Total params: 7,914,499
# Trainable params: 7,914,499
# Non-trainable params: 0
# _________________________________________________________________
# ********** Generative Adversarial Networks Model **********
# Model: "model_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_6 (InputLayer)         [(None, 1, 1, 100)]       0
# _________________________________________________________________
# model_4 (Model)              (None, 64, 64, 3)         7914499
# _________________________________________________________________
# model_3 (Model)              (None, 1)                 1235969
# =================================================================
# Total params: 9,150,468
# Trainable params: 7,914,499
# Non-trainable params: 1,235,969
# _________________________________________________________________

# %%
noise_dim = 100
EPOCHS = 10000
batch_size = 128

# %%
X = get_data()

# %%
discriminator_fake_losses = []
discriminator_real_losses = []
gan_losses = []

# %%
data_dir = 'D:/DATASET/animefaces/*.*'
save_images_dir = 'D:/projekt_output/Images8/'
chosen_face_dir = 'D:/projekt_output/One_face8/'
save_model_dir = 'D:/projekt_output/Model8/'
save_gif_dir = 'D:/projekt_output/Gif8/'

# %% [markdown]
# ### Training loop
#
# The training loop begins with generator receiving a random seed as input. That seed is used to produce an image. The discriminator is then used to classify real images and fakes images (produced by the generator). The loss is calculated for each of these models, and the gradients are used to update the generator and discriminator.
#
# We use tqdm library to display an extensible progress bar and run it for 10 000 epochs. We can see, the model learning process took 12 hours and 40 minutes.

# %%
chosen_noise = np.random.normal(0, 1, size=(batch_size,) + noise_shape)

for epoch in tqdm(range(EPOCHS)):
    
    # Get a random batch of real images
    idx = np.random.randint(0, X.shape[0], batch_size)
    real_data_X = X[idx]
    
    # Generate a batch of fake images
    noise = np.random.normal(0, 1, size=(batch_size,) + noise_shape)
    fake_data_X = generator.predict(noise)
    
    if (epoch % 50) == 0:
        plt.figure(figsize=(8, 8))
        gs1 = gs.GridSpec(8, 8)
        gs1.update(wspace=0, hspace=0)
        random_indices = np.random.choice(fake_data_X.shape[0], 64, replace=False)
        for i in range(64):
            ax1 = plt.subplot(gs1[i])
            ax1.set_aspect('equal')
            random_index = random_indices[i]
            image = fake_data_X[random_index, :, :, :]
            fig = plt.imshow(denorm_img(image))
            plt.axis('off')
            fig.axes.get_xaxis().set_visible(False)
            fig.axes.get_yaxis().set_visible(False)
        plt.tight_layout()
        plt.savefig(save_images_dir + str(epoch).zfill(5) + "_image.png", bbox_inches='tight', pad_inches=0)
        plt.close()
        
        

    # concatenate real and fake data samples
    data_X = np.concatenate([real_data_X, fake_data_X])
    #add noise to the label inputs
    real_data_Y = np.ones(batch_size) - np.random.random_sample(batch_size) * 0.2
    fake_data_Y = np.random.random_sample(batch_size) * 0.2

    data_Y = np.concatenate((real_data_Y, fake_data_Y))

    discriminator.trainable = True
    generator.trainable = False
    
    ''' Training the Discriminator'''
    
    dis_metrics_real = discriminator.train_on_batch(real_data_X, real_data_Y)
    dis_metrics_fake = discriminator.train_on_batch(fake_data_X, fake_data_Y)

    discriminator_fake_losses.append(dis_metrics_fake[0])
    discriminator_real_losses.append(dis_metrics_real[0])
    
    ''' Training the Generator '''
    
    generator.trainable = True

    GAN_X = np.random.normal(0, 1, size=(batch_size,) + noise_shape)

    GAN_Y = real_data_Y

    discriminator.trainable = False

    gan_metrics = gan.train_on_batch(GAN_X, GAN_Y)
    
    if (epoch % 1000) == 0:
        print(f"Epoch: {epoch}/{EPOCHS}")
        print("Discriminator: real loss: %f fake loss: %f" % (dis_metrics_real[0], dis_metrics_fake[0]))
        print("GAN loss: %f" % (gan_metrics[0]))

    text_file = open(save_model_dir + "\\training_log.txt", "a")
    text_file.write("Epoch: %d Discriminator: real loss: %f fake loss: %f GAN loss: %f\n" % (epoch, 
                                                                                             dis_metrics_real[0],
                                                                                             dis_metrics_fake[0], 
                                                                                             gan_metrics[0]))
    text_file.close()
    gan_losses.append(gan_metrics[0])
    
    if ((epoch + 1) % 500) == 0:
        discriminator.trainable = True
        generator.trainable = True
        generator.save(save_model_dir + str(epoch) + "_GENERATOR.hdf5")
        discriminator.save(save_model_dir + str(epoch) + "_DISCRIMINATOR.hdf5")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10000.0), HTML(value='')))
# Epoch: 0/10000
# Discriminator: real loss: 0.684863 fake loss: 0.695112
# GAN loss: 0.691994
# Epoch: 50/10000
# Discriminator: real loss: 0.375396 fake loss: 0.422156
# GAN loss: 3.063617
# Epoch: 100/10000
# Discriminator: real loss: 0.377897 fake loss: 0.339387
# GAN loss: 2.681577
# Epoch: 150/10000
# Discriminator: real loss: 0.361687 fake loss: 0.478914
# GAN loss: 2.596941
# Epoch: 200/10000
# Discriminator: real loss: 0.442568 fake loss: 0.566318
# GAN loss: 2.009719
# Epoch: 250/10000
# Discriminator: real loss: 0.377684 fake loss: 0.488712
# GAN loss: 2.981253
# Epoch: 300/10000
# Discriminator: real loss: 0.432814 fake loss: 0.335369
# GAN loss: 2.141734
# Epoch: 350/10000
# Discriminator: real loss: 0.359950 fake loss: 0.454118
# GAN loss: 2.888676
# Epoch: 400/10000
# Discriminator: real loss: 0.568114 fake loss: 0.554376
# GAN loss: 2.236770
# Epoch: 450/10000
# Discriminator: real loss: 0.383393 fake loss: 0.444117
# GAN loss: 3.698075
# Epoch: 500/10000
# Discriminator: real loss: 0.409932 fake loss: 0.363684
# GAN loss: 2.417410
# Epoch: 550/10000
# Discriminator: real loss: 0.511415 fake loss: 0.501536
# GAN loss: 2.443213
# Epoch: 600/10000
# Discriminator: real loss: 0.515143 fake loss: 0.517079
# GAN loss: 2.357549
# Epoch: 650/10000
# Discriminator: real loss: 0.459643 fake loss: 0.359424
# GAN loss: 2.063570
# Epoch: 700/10000
# Discriminator: real loss: 0.482679 fake loss: 0.459505
# GAN loss: 2.695758
# Epoch: 750/10000
# Discriminator: real loss: 0.415531 fake loss: 0.377703
# GAN loss: 2.280589
# Epoch: 800/10000
# Discriminator: real loss: 0.528627 fake loss: 0.462396
# GAN loss: 2.257690
# Epoch: 850/10000
# Discriminator: real loss: 0.598727 fake loss: 0.455545
# GAN loss: 1.985767
# Epoch: 900/10000
# Discriminator: real loss: 0.488353 fake loss: 0.503579
# GAN loss: 1.850404
# Epoch: 950/10000
# Discriminator: real loss: 0.649333 fake loss: 0.430924
# GAN loss: 1.942693
# Epoch: 1000/10000
# Discriminator: real loss: 0.616915 fake loss: 0.587687
# GAN loss: 1.638641
# Epoch: 1050/10000
# Discriminator: real loss: 0.598520 fake loss: 0.566784
# GAN loss: 2.228320
# Epoch: 1100/10000
# Discriminator: real loss: 0.543567 fake loss: 0.454329
# GAN loss: 1.783481
# Epoch: 1150/10000
# Discriminator: real loss: 0.507826 fake loss: 0.542477
# GAN loss: 1.627472
# Epoch: 1200/10000
# Discriminator: real loss: 0.598146 fake loss: 0.533702
# GAN loss: 1.660004
# Epoch: 1250/10000
# Discriminator: real loss: 0.553024 fake loss: 0.496643
# GAN loss: 1.796291
# Epoch: 1300/10000
# Discriminator: real loss: 0.573603 fake loss: 0.544768
# GAN loss: 1.418280
# Epoch: 1350/10000
# Discriminator: real loss: 0.618416 fake loss: 0.581622
# GAN loss: 1.723248
# Epoch: 1400/10000
# Discriminator: real loss: 0.678591 fake loss: 0.626105
# GAN loss: 1.446590
# Epoch: 1450/10000
# Discriminator: real loss: 0.659044 fake loss: 0.583972
# GAN loss: 1.484404
# Epoch: 1500/10000
# Discriminator: real loss: 0.537769 fake loss: 0.579846
# GAN loss: 1.578851
# Epoch: 1550/10000
# Discriminator: real loss: 0.575659 fake loss: 0.510080
# GAN loss: 1.647335
# Epoch: 1600/10000
# Discriminator: real loss: 0.616156 fake loss: 0.515740
# GAN loss: 1.581397
# Epoch: 1650/10000
# Discriminator: real loss: 0.591406 fake loss: 0.569659
# GAN loss: 1.373591
# Epoch: 1700/10000
# Discriminator: real loss: 0.602422 fake loss: 0.567336
# GAN loss: 1.465508
# Epoch: 1750/10000
# Discriminator: real loss: 0.687191 fake loss: 0.566037
# GAN loss: 1.600427
# Epoch: 1800/10000
# Discriminator: real loss: 0.628562 fake loss: 0.577132
# GAN loss: 1.382605
# Epoch: 1850/10000
# Discriminator: real loss: 0.554910 fake loss: 0.588346
# GAN loss: 1.624110
# Epoch: 1900/10000
# Discriminator: real loss: 0.665709 fake loss: 0.579404
# GAN loss: 1.460707
# Epoch: 1950/10000
# Discriminator: real loss: 0.612379 fake loss: 0.513796
# GAN loss: 1.428587
# Epoch: 2000/10000
# Discriminator: real loss: 0.597000 fake loss: 0.549230
# GAN loss: 1.363811
# Epoch: 2050/10000
# Discriminator: real loss: 0.583320 fake loss: 0.604089
# GAN loss: 1.526809
# Epoch: 2100/10000
# Discriminator: real loss: 0.625876 fake loss: 0.594776
# GAN loss: 1.426255
# Epoch: 2150/10000
# Discriminator: real loss: 0.598013 fake loss: 0.593247
# GAN loss: 1.420596
# Epoch: 2200/10000
# Discriminator: real loss: 0.617952 fake loss: 0.547276
# GAN loss: 1.365430
# Epoch: 2250/10000
# Discriminator: real loss: 0.663291 fake loss: 0.596959
# GAN loss: 1.327752
# Epoch: 2300/10000
# Discriminator: real loss: 0.549395 fake loss: 0.668907
# GAN loss: 1.322023
# Epoch: 2350/10000
# Discriminator: real loss: 0.661991 fake loss: 0.544120
# GAN loss: 1.323452
# Epoch: 2400/10000
# Discriminator: real loss: 0.541694 fake loss: 0.563069
# GAN loss: 1.289439
# Epoch: 2450/10000
# Discriminator: real loss: 0.612975 fake loss: 0.599107
# GAN loss: 1.188926
# Epoch: 2500/10000
# Discriminator: real loss: 0.549429 fake loss: 0.577821
# GAN loss: 1.232444
# Epoch: 2550/10000
# Discriminator: real loss: 0.624356 fake loss: 0.593248
# GAN loss: 1.180061
# Epoch: 2600/10000
# Discriminator: real loss: 0.604762 fake loss: 0.581790
# GAN loss: 1.210105
# Epoch: 2650/10000
# Discriminator: real loss: 0.582607 fake loss: 0.624112
# GAN loss: 1.276740
# Epoch: 2700/10000
# Discriminator: real loss: 0.586388 fake loss: 0.588842
# GAN loss: 1.298951
# Epoch: 2750/10000
# Discriminator: real loss: 0.627277 fake loss: 0.567820
# GAN loss: 1.253893
# Epoch: 2800/10000
# Discriminator: real loss: 0.658802 fake loss: 0.657191
# GAN loss: 1.302367
# Epoch: 2850/10000
# Discriminator: real loss: 0.655407 fake loss: 0.577809
# GAN loss: 1.181589
# Epoch: 2900/10000
# Discriminator: real loss: 0.667542 fake loss: 0.614810
# GAN loss: 1.144948
# Epoch: 2950/10000
# Discriminator: real loss: 0.645406 fake loss: 0.685143
# GAN loss: 1.242224
# Epoch: 3000/10000
# Discriminator: real loss: 0.638034 fake loss: 0.670743
# GAN loss: 1.172800
# Epoch: 3050/10000
# Discriminator: real loss: 0.643747 fake loss: 0.586590
# GAN loss: 1.161929
# Epoch: 3100/10000
# Discriminator: real loss: 0.589554 fake loss: 0.673509
# GAN loss: 1.205805
# Epoch: 3150/10000
# Discriminator: real loss: 0.720924 fake loss: 0.573805
# GAN loss: 1.093128
# Epoch: 3200/10000
# Discriminator: real loss: 0.630946 fake loss: 0.618325
# GAN loss: 1.175187
# Epoch: 3250/10000
# Discriminator: real loss: 0.641002 fake loss: 0.612293
# GAN loss: 1.101737
# Epoch: 3300/10000
# Discriminator: real loss: 0.665097 fake loss: 0.630736
# GAN loss: 1.160365
# Epoch: 3350/10000
# Discriminator: real loss: 0.601323 fake loss: 0.582044
# GAN loss: 1.164389
# Epoch: 3400/10000
# Discriminator: real loss: 0.606012 fake loss: 0.679251
# GAN loss: 1.092889
# Epoch: 3450/10000
# Discriminator: real loss: 0.680536 fake loss: 0.594241
# GAN loss: 1.201774
# Epoch: 3500/10000
# Discriminator: real loss: 0.633383 fake loss: 0.611188
# GAN loss: 1.019558
# Epoch: 3550/10000
# Discriminator: real loss: 0.620613 fake loss: 0.661806
# GAN loss: 1.080587
# Epoch: 3600/10000
# Discriminator: real loss: 0.680014 fake loss: 0.640223
# GAN loss: 1.077238
# Epoch: 3650/10000
# Discriminator: real loss: 0.659527 fake loss: 0.583374
# GAN loss: 1.145934
# Epoch: 3700/10000
# Discriminator: real loss: 0.653198 fake loss: 0.627826
# GAN loss: 1.018316
# Epoch: 3750/10000
# Discriminator: real loss: 0.693585 fake loss: 0.621083
# GAN loss: 1.062404
# Epoch: 3800/10000
# Discriminator: real loss: 0.667864 fake loss: 0.639075
# GAN loss: 1.023611
# Epoch: 3850/10000
# Discriminator: real loss: 0.610497 fake loss: 0.586886
# GAN loss: 1.196855
# Epoch: 3900/10000
# Discriminator: real loss: 0.685662 fake loss: 0.642286
# GAN loss: 1.023725
# Epoch: 3950/10000
# Discriminator: real loss: 0.653685 fake loss: 0.618876
# GAN loss: 1.048420
# Epoch: 4000/10000
# Discriminator: real loss: 0.647447 fake loss: 0.580819
# GAN loss: 1.097849
# Epoch: 4050/10000
# Discriminator: real loss: 0.663861 fake loss: 0.699894
# GAN loss: 0.979714
# Epoch: 4100/10000
# Discriminator: real loss: 0.666414 fake loss: 0.609502
# GAN loss: 1.104252
# Epoch: 4150/10000
# Discriminator: real loss: 0.634838 fake loss: 0.616387
# GAN loss: 1.119988
# Epoch: 4200/10000
# Discriminator: real loss: 0.636589 fake loss: 0.678141
# GAN loss: 1.045249
# Epoch: 4250/10000
# Discriminator: real loss: 0.664877 fake loss: 0.612953
# GAN loss: 1.101748
# Epoch: 4300/10000
# Discriminator: real loss: 0.698944 fake loss: 0.604739
# GAN loss: 1.007668
# Epoch: 4350/10000
# Discriminator: real loss: 0.679585 fake loss: 0.670208
# GAN loss: 0.991292
# Epoch: 4400/10000
# Discriminator: real loss: 0.670210 fake loss: 0.737408
# GAN loss: 1.102421
# Epoch: 4450/10000
# Discriminator: real loss: 0.631644 fake loss: 0.665259
# GAN loss: 0.967141
# Epoch: 4500/10000
# Discriminator: real loss: 0.679935 fake loss: 0.611187
# GAN loss: 0.916731
# Epoch: 4550/10000
# Discriminator: real loss: 0.677587 fake loss: 0.649033
# GAN loss: 0.993812
# Epoch: 4600/10000
# Discriminator: real loss: 0.602965 fake loss: 0.663445
# GAN loss: 1.050378
# Epoch: 4650/10000
# Discriminator: real loss: 0.670884 fake loss: 0.653402
# GAN loss: 0.982551
# Epoch: 4700/10000
# Discriminator: real loss: 0.632720 fake loss: 0.661680
# GAN loss: 1.090811
# Epoch: 4750/10000
# Discriminator: real loss: 0.659844 fake loss: 0.603716
# GAN loss: 1.059371
# Epoch: 4800/10000
# Discriminator: real loss: 0.608691 fake loss: 0.653412
# GAN loss: 0.908387
# Epoch: 4850/10000
# Discriminator: real loss: 0.654984 fake loss: 0.611325
# GAN loss: 1.090497
# Epoch: 4900/10000
# Discriminator: real loss: 0.621151 fake loss: 0.701251
# GAN loss: 0.972044
# Epoch: 4950/10000
# Discriminator: real loss: 0.625276 fake loss: 0.653193
# GAN loss: 0.933400
# Epoch: 5000/10000
# Discriminator: real loss: 0.674544 fake loss: 0.627247
# GAN loss: 0.942313
# Epoch: 5050/10000
# Discriminator: real loss: 0.685759 fake loss: 0.632666
# GAN loss: 0.935111
# Epoch: 5100/10000
# Discriminator: real loss: 0.671835 fake loss: 0.614635
# GAN loss: 1.000612
# Epoch: 5150/10000
# Discriminator: real loss: 0.643848 fake loss: 0.700835
# GAN loss: 1.048411
# Epoch: 5200/10000
# Discriminator: real loss: 0.652176 fake loss: 0.630996
# GAN loss: 0.957549
# Epoch: 5250/10000
# Discriminator: real loss: 0.702498 fake loss: 0.674762
# GAN loss: 0.974383
# Epoch: 5300/10000
# Discriminator: real loss: 0.630089 fake loss: 0.644547
# GAN loss: 0.934387
# Epoch: 5350/10000
# Discriminator: real loss: 0.661092 fake loss: 0.626979
# GAN loss: 0.992584
# Epoch: 5400/10000
# Discriminator: real loss: 0.705034 fake loss: 0.652372
# GAN loss: 0.935374
# Epoch: 5450/10000
# Discriminator: real loss: 0.617800 fake loss: 0.681695
# GAN loss: 0.950371
# Epoch: 5500/10000
# Discriminator: real loss: 0.678863 fake loss: 0.674288
# GAN loss: 0.968454
# Epoch: 5550/10000
# Discriminator: real loss: 0.620372 fake loss: 0.618072
# GAN loss: 1.026508
# Epoch: 5600/10000
# Discriminator: real loss: 0.679929 fake loss: 0.632499
# GAN loss: 0.915689
# Epoch: 5650/10000
# Discriminator: real loss: 0.670748 fake loss: 0.678642
# GAN loss: 0.899650
# Epoch: 5700/10000
# Discriminator: real loss: 0.646016 fake loss: 0.698744
# GAN loss: 0.955858
# Epoch: 5750/10000
# Discriminator: real loss: 0.663226 fake loss: 0.687026
# GAN loss: 0.960736
# Epoch: 5800/10000
# Discriminator: real loss: 0.666562 fake loss: 0.643199
# GAN loss: 0.891079
# Epoch: 5850/10000
# Discriminator: real loss: 0.673960 fake loss: 0.679331
# GAN loss: 0.891045
# Epoch: 5900/10000
# Discriminator: real loss: 0.681648 fake loss: 0.641274
# GAN loss: 0.967751
# Epoch: 5950/10000
# Discriminator: real loss: 0.698426 fake loss: 0.639422
# GAN loss: 0.879623
# Epoch: 6000/10000
# Discriminator: real loss: 0.623998 fake loss: 0.671447
# GAN loss: 0.932368
# Epoch: 6050/10000
# Discriminator: real loss: 0.667426 fake loss: 0.649835
# GAN loss: 0.946012
# Epoch: 6100/10000
# Discriminator: real loss: 0.662076 fake loss: 0.630764
# GAN loss: 0.943680
# Epoch: 6150/10000
# Discriminator: real loss: 0.645789 fake loss: 0.710062
# GAN loss: 0.887252
# Epoch: 6200/10000
# Discriminator: real loss: 0.641977 fake loss: 0.668894
# GAN loss: 0.931103
# Epoch: 6250/10000
# Discriminator: real loss: 0.594508 fake loss: 0.631381
# GAN loss: 0.974331
# Epoch: 6300/10000
# Discriminator: real loss: 0.749010 fake loss: 0.622340
# GAN loss: 0.984471
# Epoch: 6350/10000
# Discriminator: real loss: 0.619477 fake loss: 0.664176
# GAN loss: 0.948906
# Epoch: 6400/10000
# Discriminator: real loss: 0.668179 fake loss: 0.659850
# GAN loss: 0.922232
# Epoch: 6450/10000
# Discriminator: real loss: 0.680665 fake loss: 0.666404
# GAN loss: 0.898610
# Epoch: 6500/10000
# Discriminator: real loss: 0.686497 fake loss: 0.634400
# GAN loss: 0.947991
# Epoch: 6550/10000
# Discriminator: real loss: 0.654926 fake loss: 0.674643
# GAN loss: 0.883409
# Epoch: 6600/10000
# Discriminator: real loss: 0.671357 fake loss: 0.685059
# GAN loss: 0.988065
# Epoch: 6650/10000
# Discriminator: real loss: 0.679293 fake loss: 0.701645
# GAN loss: 0.870490
# Epoch: 6700/10000
# Discriminator: real loss: 0.690376 fake loss: 0.631866
# GAN loss: 0.991171
# Epoch: 6750/10000
# Discriminator: real loss: 0.656526 fake loss: 0.663101
# GAN loss: 0.898892
# Epoch: 6800/10000
# Discriminator: real loss: 0.685451 fake loss: 0.689945
# GAN loss: 0.982567
# Epoch: 6850/10000
# Discriminator: real loss: 0.640586 fake loss: 0.642562
# GAN loss: 0.895787
# Epoch: 6900/10000
# Discriminator: real loss: 0.659170 fake loss: 0.650403
# GAN loss: 0.931270
# Epoch: 6950/10000
# Discriminator: real loss: 0.634678 fake loss: 0.666158
# GAN loss: 0.909848
# Epoch: 7000/10000
# Discriminator: real loss: 0.657744 fake loss: 0.636239
# GAN loss: 0.926296
# Epoch: 7050/10000
# Discriminator: real loss: 0.587184 fake loss: 0.807452
# GAN loss: 0.966558
# Epoch: 7100/10000
# Discriminator: real loss: 0.671247 fake loss: 0.654045
# GAN loss: 0.908686
# Epoch: 7150/10000
# Discriminator: real loss: 0.648003 fake loss: 0.702266
# GAN loss: 0.909742
# Epoch: 7200/10000
# Discriminator: real loss: 0.691181 fake loss: 0.661541
# GAN loss: 0.867816
# Epoch: 7250/10000
# Discriminator: real loss: 0.700846 fake loss: 0.615146
# GAN loss: 0.888395
# Epoch: 7300/10000
# Discriminator: real loss: 0.700022 fake loss: 0.654717
# GAN loss: 0.851899
# Epoch: 7350/10000
# Discriminator: real loss: 0.653987 fake loss: 0.662230
# GAN loss: 0.864325
# Epoch: 7400/10000
# Discriminator: real loss: 0.668937 fake loss: 0.677870
# GAN loss: 0.880872
# Epoch: 7450/10000
# Discriminator: real loss: 0.643119 fake loss: 0.646062
# GAN loss: 0.872224
# Epoch: 7500/10000
# Discriminator: real loss: 0.618837 fake loss: 0.677435
# GAN loss: 0.917184
# Epoch: 7550/10000
# Discriminator: real loss: 0.626590 fake loss: 0.652478
# GAN loss: 0.964659
# Epoch: 7600/10000
# Discriminator: real loss: 0.697116 fake loss: 0.677482
# GAN loss: 0.946788
# Epoch: 7650/10000
# Discriminator: real loss: 0.638014 fake loss: 0.675335
# GAN loss: 0.890821
# Epoch: 7700/10000
# Discriminator: real loss: 0.704773 fake loss: 0.700812
# GAN loss: 0.878311
# Epoch: 7750/10000
# Discriminator: real loss: 0.685950 fake loss: 0.643598
# GAN loss: 0.947069
# Epoch: 7800/10000
# Discriminator: real loss: 0.602171 fake loss: 0.701008
# GAN loss: 0.875166
# Epoch: 7850/10000
# Discriminator: real loss: 0.703834 fake loss: 0.687462
# GAN loss: 0.909402
# Epoch: 7900/10000
# Discriminator: real loss: 0.710645 fake loss: 0.602904
# GAN loss: 0.915800
# Epoch: 7950/10000
# Discriminator: real loss: 0.651996 fake loss: 0.655164
# GAN loss: 0.882820
# Epoch: 8000/10000
# Discriminator: real loss: 0.687266 fake loss: 0.674587
# GAN loss: 0.948375
# Epoch: 8050/10000
# Discriminator: real loss: 0.660610 fake loss: 0.698090
# GAN loss: 0.869574
# Epoch: 8100/10000
# Discriminator: real loss: 0.684569 fake loss: 0.649865
# GAN loss: 0.916664
# Epoch: 8150/10000
# Discriminator: real loss: 0.669007 fake loss: 0.659089
# GAN loss: 0.878859
# Epoch: 8200/10000
# Discriminator: real loss: 0.662559 fake loss: 0.621833
# GAN loss: 0.924350
# Epoch: 8250/10000
# Discriminator: real loss: 0.647206 fake loss: 0.649416
# GAN loss: 0.863390
# Epoch: 8300/10000
# Discriminator: real loss: 0.701240 fake loss: 0.682945
# GAN loss: 0.895812
# Epoch: 8350/10000
# Discriminator: real loss: 0.679566 fake loss: 0.637478
# GAN loss: 0.946770
# Epoch: 8400/10000
# Discriminator: real loss: 0.676439 fake loss: 0.668809
# GAN loss: 1.028033
# Epoch: 8450/10000
# Discriminator: real loss: 0.630992 fake loss: 0.680481
# GAN loss: 0.942861
# Epoch: 8500/10000
# Discriminator: real loss: 0.667739 fake loss: 0.702959
# GAN loss: 0.859354
# Epoch: 8550/10000
# Discriminator: real loss: 0.623431 fake loss: 0.675729
# GAN loss: 0.894119
# Epoch: 8600/10000
# Discriminator: real loss: 0.639520 fake loss: 0.683832
# GAN loss: 0.874130
# Epoch: 8650/10000
# Discriminator: real loss: 0.681446 fake loss: 0.652638
# GAN loss: 0.921341
# Epoch: 8700/10000
# Discriminator: real loss: 0.669575 fake loss: 0.651917
# GAN loss: 0.896778
# Epoch: 8750/10000
# Discriminator: real loss: 0.682378 fake loss: 0.692726
# GAN loss: 0.905307
# Epoch: 8800/10000
# Discriminator: real loss: 0.649437 fake loss: 0.649066
# GAN loss: 0.918659
# Epoch: 8850/10000
# Discriminator: real loss: 0.691290 fake loss: 0.684900
# GAN loss: 0.963496
# Epoch: 8900/10000
# Discriminator: real loss: 0.690013 fake loss: 0.673885
# GAN loss: 0.903484
# Epoch: 8950/10000
# Discriminator: real loss: 0.673520 fake loss: 0.667875
# GAN loss: 0.863826
# Epoch: 9000/10000
# Discriminator: real loss: 0.631316 fake loss: 0.645250
# GAN loss: 0.861346
# Epoch: 9050/10000
# Discriminator: real loss: 0.647328 fake loss: 0.766226
# GAN loss: 0.950424
# Epoch: 9100/10000
# Discriminator: real loss: 0.659103 fake loss: 0.660597
# GAN loss: 0.918151
# Epoch: 9150/10000
# Discriminator: real loss: 0.680758 fake loss: 0.625856
# GAN loss: 0.956314
# Epoch: 9200/10000
# Discriminator: real loss: 0.672667 fake loss: 0.621583
# GAN loss: 0.934761
# Epoch: 9250/10000
# Discriminator: real loss: 0.638318 fake loss: 0.686231
# GAN loss: 0.874632
# Epoch: 9300/10000
# Discriminator: real loss: 0.698175 fake loss: 0.662535
# GAN loss: 0.945916
# Epoch: 9350/10000
# Discriminator: real loss: 0.642702 fake loss: 0.657156
# GAN loss: 0.906750
# Epoch: 9400/10000
# Discriminator: real loss: 0.695713 fake loss: 0.668430
# GAN loss: 0.858167
# Epoch: 9450/10000
# Discriminator: real loss: 0.660926 fake loss: 0.631657
# GAN loss: 0.899546
# Epoch: 9500/10000
# Discriminator: real loss: 0.666890 fake loss: 0.634061
# GAN loss: 0.919918
# Epoch: 9550/10000
# Discriminator: real loss: 0.656679 fake loss: 0.683833
# GAN loss: 0.906118
# Epoch: 9600/10000
# Discriminator: real loss: 0.719761 fake loss: 0.648919
# GAN loss: 0.999594
# Epoch: 9650/10000
# Discriminator: real loss: 0.642833 fake loss: 0.615379
# GAN loss: 0.845780
# Epoch: 9700/10000
# Discriminator: real loss: 0.695411 fake loss: 0.658002
# GAN loss: 0.919025
# Epoch: 9750/10000
# Discriminator: real loss: 0.670081 fake loss: 0.656936
# GAN loss: 0.920556
# Epoch: 9800/10000
# Discriminator: real loss: 0.656672 fake loss: 0.664084
# GAN loss: 0.940220
# Epoch: 9850/10000
# Discriminator: real loss: 0.665352 fake loss: 0.682738
# GAN loss: 0.960744
# Epoch: 9900/10000
# Discriminator: real loss: 0.680718 fake loss: 0.628647
# GAN loss: 0.941413
# Epoch: 9950/10000
# Discriminator: real loss: 0.630001 fake loss: 0.635843
# GAN loss: 0.916189

# %%
''' Exporting the results to csv'''

df = pd.DataFrame({
        'epochs': list(range(10000)),
        'disc_fake_loss': discriminator_fake_losses[:10000],
        'disc_real_loss': discriminator_real_losses[:10000],
        'gan_loss': gan_losses[:10000]
    }).set_index('epochs')

# %%
df['mean_disc_loss'] = (df.disc_fake_loss + df.disc_real_loss) / 2

# %%
df.to_csv(save_model_dir+'losses.csv')

# %% [markdown]
# ## 4. Creating charts, images and gif.

# %%
seaborn.set_style('darkgrid')

# %%
plt.figure(figsize=(14,6))
plt.plot(df['gan_loss'], label='GAN losses')
plt.plot(df['mean_disc_loss'], label='Mean discriminator losses')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc=1,prop={'size': 14})
plt.title('Losses, epoch: 1 to 10 000', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.plot(df['gan_loss'][1000:], label='GAN losses')
plt.plot(df['mean_disc_loss'][1000:], label='Mean discriminator losses')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc=1,prop={'size': 14})
plt.title('Losses, epoch: 500 to 10 000', fontsize=20)
plt.show()

# %%
plt.figure(figsize=(14,6))
plt.plot(df['disc_fake_loss'], label='Discriminator fake images losses')
plt.plot(df['disc_real_loss'], label='Discriminator real images losses')
plt.xlabel('Epochs', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.legend(loc=1,prop={'size': 14})
plt.title('Discriminator losses, epoch: 1 to 10 000', fontsize=20)
plt.show()

# %%
'''Creating a gif from our generated images''' 

frames = []
imgs = glob.glob(r"D:\projekt_output\Images8\*.png")
for i in imgs:
    new_frame = Image.open(i)
    frames.append(new_frame)
 
frames[0].save(r'D:\projekt_output\Gif8\png_to_gif.gif', format='GIF',
               append_images=frames[1:],
               save_all=True,
               duration=100, loop=1)

# %% [markdown]
# Sample of real and generated images.

# %%
''' Generated images'''
plt.figure(figsize=(8, 8))
gs1 = gs.GridSpec(8, 8)
gs1.update(wspace=0, hspace=0)

random_indices = np.random.choice(fake_data_X.shape[0], 64, replace=False)
for i in range(64):
    ax1 = plt.subplot(gs1[i])
    ax1.set_aspect('equal')
    random_index = random_indices[i]
    image = fake_data_X[random_index, :, :, :]
    fig = plt.imshow(denorm_img(image))
    plt.axis('off')
    fig.axes.get_xaxis().set_visible(False)
    fig.axes.get_yaxis().set_visible(False)
plt.tight_layout()
plt.savefig(save_images_dir + str(epoch).zfill(5) + "_image.png", bbox_inches='tight', pad_inches=0)
plt.show()

# %%
'''Real images'''
plt.figure(figsize=(8, 8))
gs1 = gs.GridSpec(8, 8)
gs1.update(wspace=0, hspace=0)

idx = np.random.randint(0, X.shape[0], batch_size)
real_data_X = X[idx]

for i in range(64):
    ax1 = plt.subplot(gs1[i])
    ax1.set_aspect('equal')
    random_index = random_indices[i]
    image = real_data_X[random_index, :, :, :]
    fig = plt.imshow(denorm_img(image))
    plt.axis('off')
    fig.axes.get_xaxis().set_visible(False)
    fig.axes.get_yaxis().set_visible(False)
plt.tight_layout()
plt.savefig(save_gif_dir + "real_image.png", bbox_inches='tight', pad_inches=0)
plt.show()

# %%
models = []
model0 = {f'model0': load_model(dd+'499_GENERATOR.hdf5')}
models.append(model0)
step = 999
for i in range(1,11):
    model = {f'model{i}': load_model(dd+f'{step}_GENERATOR.hdf5')}
    models.append(model)
    step += 1000

# %%
chosen_noise = np.random.normal(0, 1, size=(batch_size,) + noise_shape)

# %%
list_generators = []
for i in range(11):
    z = models[i].predict(chosen_noise)
    list_generators.append(z)
    i +=1

# %%
fig, axes = plt.subplots(6, 11, figsize=(20,20),
                         gridspec_kw={'hspace': -0.825, 'wspace': 0})
count = 3
for i in range(6):
    for j in range(11):
        image = list_generators[j][count, :, :, :]
        axes[i, j].imshow(denorm_img(image))
        axes[i, j].axis('off')
    
    count += 4
    
fig.text(0.1, 0.5, 'Faces', ha='center', va='center', rotation='vertical', fontsize=18)
    
step = 0
axes[5,0].set_title('epoch = 500', fontsize=12, x=0.5, y= -0.25)
for l in range(1, 11):
    axes[5,l].set_title(f'epoch = {step+1000}', fontsize=12, x=0.5, y= -0.25)
    step += 1000
plt.show()
